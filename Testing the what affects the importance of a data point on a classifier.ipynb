# %% [markdown]
# # Few tests that will be done.
# Initial testing using the complete training set.
#     •	Points close to the hyperplane
#     •	Far from the hyperplane
#     •	On the hyperplane
#     •	Middle area
#     •	Top
#     •	bottom
#
# Distance from the ideal class
#     o	Just by the hyperplane
#     o	Far from the hyperplane
#     o	Then again but at either ends Eg top and bottom to see if it will change the hyper plane.
#     o	Few random points testing to see how much it affects the classifier. (such as few spots near the middle, one at bottom one at top etc)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
from sklearn import svm
from sklearn.metrics import accuracy_score
X1 = np.array([
              [1,2,-1],[2,3,-1],[3,4,-1],[4,7,-1],[7,8,-1],[8,9,-1],[9,10,-1],[10,1,1],
              [1,3,-1],[2,4,-1],[3,7,-1],[4,8,-1],[7,9,-1],[8,10,-1],[9,1,1],[10,2,1],
              [1,4,-1],[2,7,-1],[3,8,-1],[4,9,-1],[7,10,-1],[8,1,1],[9,2,1],[10,3,1],
              
              [5,4,1],[5,7,-1],[5,8,-1],[5,9,-1],[5,10,-1],[5,1,1],[5,2,1],[5,3,1],
              [6,4,1],[6,7,-1],[6,8,-1],[6,9,-1],[6,10,-1],[6,1,1],[6,2,1],[6,3,1],
              [5,6,-1], [6,5,1],    
              
              [1,7,-1],[2,8,-1],[3,9,-1],[4,10,-1],[7,1,1],[8,2,1],[9,3,1],[10,4,1],
              [1,8,-1],[2,9,-1],[3,10,-1],[4,1,1],[7,2,1],[8,3,1],[9,4,1],[10,7,1],
              [1,9,-1],[2,10,-1],[3,1,1],[4,2,1],[7,3,1],[8,4,1],[9,7,1],[10,8,1],
              [1,10,-1],[2,1,1],[3,2,1],[4,3,1],[7,4,1],[8,7,1],[9,8,1],[10,9,1],
              [1,5,-1],[2,5,-1],[3,5,-1],[4,5,-1],[7,5,1],[8,5,1],[9,5,1],[10,5,1],
              [1,6,-1],[2,6,-1],[3,6,-1],[4,6,-1],[7,6,1],[8,6,1],[9,6,1],[10,6,1]
             ])
#Traiin classifier 
model = svm.SVC(kernel='linear', C=1.0).fit(X1[:,:-1], X1[:,-1])


# Get axis limits and create a grid to evaluate the model upon.
ax = plt.gca()
xx = np.linspace(0, 12)
yy = np.linspace(0, 12 )
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy).reshape(XX.shape)

# Plot decision boundary and margins.
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# Highlight the support vectors.
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
student_0 = model.predict([[10,10],
                          [5.5,5.5]])

# show the plot visually
plt.scatter(X1[:, 0], X1[:, 1],c=X1[:,-1])
plt.xlim(0,12)
plt.ylim(0,12)
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
X = np.array([
              [1,2,-1],[2,3,-1],[3,4,-1],[8,9,-1],[9,10,-1],
              [4,5,-1],[5,6,-1],[6,7,-1],
              [5,4,1],
              [7,8,-1],
              [6,5,1],    
              [2,1,1],[3,2,1],[4,3,1],[8,7,1],[9,8,1],[10,9,1],
              [7,6,1]
              
             ])

model = svm.SVC(kernel='linear', C=1.0).fit(X[:,:-1], X[:,-1])


# Get axis limits and create a grid to evaluate the model upon.
ax = plt.gca()
xx = np.linspace(0, 12)
yy = np.linspace(0, 12 )
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy).reshape(XX.shape)

# Plot decision boundary and margins.
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# Highlight the support vectors.
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
student_0 = model.predict([[10,10],
                          [5.5,5.5]])

# show the plot visually
plt.scatter(X[:, 0], X[:, 1],c=X[:,-1])
plt.xlim(0,12)
plt.ylim(0,12)
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# This version will be testing the difference it has on the hyperplane when the points are close to the wanted hyperplane.

# %%
X = np.array([
              [1,2,-1],[9,10,-1],
                
              [2,1,1],[10,9,1]
            
              
             ])

model = svm.SVC(kernel='linear', C=1.0).fit(X[:,:-1], X[:,-1])


# Get axis limits and create a grid to evaluate the model upon.
ax = plt.gca()

xx = np.linspace(0, 12)
yy = np.linspace(0, 12 )
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy).reshape(XX.shape)

# Plot decision boundary and margins.
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# Highlight the support vectors.
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
student_0 = model.predict([[10,10],
                          [5.5,5.5]])

# show the plot visually
plt.scatter(X[:, 0], X[:, 1],c=X[:,-1])
plt.xlim(0,12)
plt.ylim(0,12)
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
#this worked exaclty as we thought with the lines spread out it 
#would simply use them as the support vectors and generate an accurate hyperplane.
# Out:
# No handles with labels found to put in legend.

# %%
X = np.array([
              [5,6,-1],[6,7,-1],
                
              [6,5,1],[7,6,1]
            
              
             ])

model = svm.SVC(kernel='linear', C=1.0).fit(X[:,:-1], X[:,-1])


# Get axis limits and create a grid to evaluate the model upon.
ax = plt.gca()

xx = np.linspace(0, 12)
yy = np.linspace(0, 12 )
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy).reshape(XX.shape)

# Plot decision boundary and margins.
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# Highlight the support vectors.
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
student_0 = model.predict([[10,10],
                          [5.5,5.5]])

# show the plot visually
plt.scatter(X[:, 0], X[:, 1],c=X[:,-1])
plt.xlim(0,12)
plt.ylim(0,12)
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
#same again as the points line on a line perfecting in line with the 
#hyperplane if you have 2 points on either side it generates a correct hyperplane

# %%
X = np.array([
              [3,4,-1],[4,5,-1],
                
              [4,3,1],[5,4,1]
            
              
             ])

model = svm.SVC(kernel='linear', C=1.0).fit(X[:,:-1], X[:,-1])


# Get axis limits and create a grid to evaluate the model upon.
ax = plt.gca()

xx = np.linspace(0, 12)
yy = np.linspace(0, 12 )
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy).reshape(XX.shape)

# Plot decision boundary and margins.
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# Highlight the support vectors.
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
student_0 = model.predict([[10,10],
                          [5.5,5.5]])

# show the plot visually
plt.scatter(X[:, 0], X[:, 1],c=X[:,-1])
plt.xlim(0,12)
plt.ylim(0,12)
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
#same again as the points line on a line perfecting in line with the 
#hyperplane if you have 2 points on either side it generates a correct hyperplane
# Out:
# No handles with labels found to put in legend.

# %%
X = np.array([
              [1,4,-1],[4,10,-1],
                
              [4,1,1],[7,8,1]
            
              
             ])

model = svm.SVC(kernel='linear', C=1.0).fit(X[:,:-1], X[:,-1])


# Get axis limits and create a grid to evaluate the model upon.
ax = plt.gca()

xx = np.linspace(0, 12)
yy = np.linspace(0, 12 )
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy).reshape(XX.shape)

# Plot decision boundary and margins.
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# Highlight the support vectors.
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
student_0 = model.predict([[10,10],
                          [5.5,5.5]])

# show the plot visually
plt.scatter(X[:, 0], X[:, 1],c=X[:,-1])
plt.xlim(0,12)
plt.ylim(0,12)
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
#same again as the points line on a line perfecting in line with the 
#hyperplane if you have 2 points on either side it generates a correct hyperplane
print(accuracy_score(np.array(X1)[:,-1], np.array(student_0)) * 100)
print(accuracy_score(np.array(X1)[:,-1], np.array(student_0), normalize=False))
# Out:
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-158726566f66> in <module>
#      38 #same again as the points line on a line perfecting in line with the
#      39 #hyperplane if you have 2 points on either side it generates a correct hyperplane
# ---> 40 print(accuracy_score(np.array(X1)[:,-1], np.array(student_0)) * 100)
#      41 print(accuracy_score(np.array(X1)[:,-1], np.array(student_0), normalize=False))
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     183
#     184     # Compute accuracy for each possible representation
# --> 185     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     186     check_consistent_length(y_true, y_pred, sample_weight)
#     187     if y_type.startswith('multilabel'):
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      78     y_pred : array or indicator matrix
#      79     """
# ---> 80     check_consistent_length(y_true, y_pred)
#      81     type_true = type_of_target(y_true)
#      82     type_pred = type_of_target(y_pred)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
#     211         raise ValueError("Found input variables with inconsistent numbers of"
# --> 212                          " samples: %r" % [int(l) for l in lengths])
#     213
#     214
#
# ValueError: Found input variables with inconsistent numbers of samples: [90, 2]

# %%
#So from this we can see that the svm hyperplane is changed mainly through
#the angle of the support vectors. if we have points along the chosen hyperplane
#then it will be accuracte but if we deviate too much then it will change its direction
#next we will test how adding more points will affect the classifier as simply moving
#points but keeping them in the same angle as the desired hyperplane generates the same hyperplane.

# %%
test = np.array([
              [1,2],[2,3],[3,4],[4,7],[7,8],[8,9],[9,10],[10,1],
              [1,3],[2,4],[3,7],[4,8],[7,9],[8,10],[9,1],[10,2],
              [1,4],[2,7],[3,8],[4,9],[7,10],[8,1],[9,2],[10,3],
              
              [5,4],[5,7],[5,8],[5,9],[5,10],[5,1],[5,2],[5,3],
              [6,4],[6,7],[6,8],[6,9],[6,10],[6,1],[6,2],[6,3],
              [5,6],[6,5],    
              
              [1,7],[2,8],[3,9],[4,10],[7,1],[8,2],[9,3],[10,4],
              [1,8],[2,9],[3,10],[4,1],[7,2],[8,3],[9,4],[10,7],
              [1,9],[2,10],[3,1],[4,2],[7,3],[8,4],[9,7],[10,8],
              [1,10],[2,1],[3,2],[4,3],[7,4],[8,7],[9,8],[10,9],
              [1,5],[2,5],[3,5],[4,5],[7,5],[8,5],[9,5],[10,5],
              [1,6],[2,6],[3,6],[4,6],[7,6],[8,6],[9,6],[10,6]
             ])
X = np.array([
              [1,2,-1],[9,10,-1],
                
              [2,1,1],[10,9,1]
            
              
             ])

model = svm.SVC(kernel='linear', C=1.0).fit(X[:,:-1], X[:,-1])


# Get axis limits and create a grid to evaluate the model upon.
ax = plt.gca()

xx = np.linspace(0, 12)
yy = np.linspace(0, 12 )
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy).reshape(XX.shape)

# Plot decision boundary and margins.
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# Highlight the support vectors.
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')
student_0 = model.predict([[10,10],
                          [5.5,5.5]])

# show the plot visually
plt.scatter(X[:, 0], X[:, 1],c=X[:,-1])
plt.xlim(0,12)
plt.ylim(0,12)
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
prediction = model.predict(test)

ax.contour(XX, YY, Z, alpha=0.5)
print(student_0)
plt.show()

# Calculate the percentage accuracy rate on test set
accuracy = np.sum(np.equal(X1[:,-1], prediction) / X[:,-1].shape[0] * 100)
print('Percentage accuracy on testing set is: {0:.2f}%'.format(accuracy))
# Out:
# No handles with labels found to put in legend.
# [1 1]
# Percentage accuracy on testing set is: 2250.00%

# %%
test = np.array([
              [1,2],[2,3],[3,4],[4,7],[7,8],[8,9],[9,10],[10,1],
              [1,3],[2,4],[3,7],[4,8],[7,9],[8,10],[9,1],[10,2],
              [1,4],[2,7],[3,8],[4,9],[7,10],[8,1],[9,2],[10,3],
              
              [5,4],[5,7],[5,8],[5,9],[5,10],[5,1],[5,2],[5,3],
              [6,4],[6,7],[6,8],[6,9],[6,10],[6,1],[6,2],[6,3],
              [5,6],[6,5],    
              
              [1,7],[2,8],[3,9],[4,10],[7,1],[8,2],[9,3],[10,4],
              [1,8],[2,9],[3,10],[4,1],[7,2],[8,3],[9,4],[10,7],
              [1,9],[2,10],[3,1],[4,2],[7,3],[8,4],[9,7],[10,8],
              [1,10],[2,1],[3,2],[4,3],[7,4],[8,7],[9,8],[10,9],
              [1,5],[2,5],[3,5],[4,5],[7,5],[8,5],[9,5],[10,5],
              [1,6],[2,6],[3,6],[4,6],[7,6],[8,6],[9,6],[10,6]
             ])

X = np.array([
              [1,2,-1],[2,3,-1],[3,4,-1],[4,7,-1],[7,8,-1],[8,9,-1],[9,10,-1],[10,1,1],
              [1,3,-1],[2,4,-1],[3,7,-1],[4,8,-1],[7,9,-1],[8,10,-1],[9,1,1],[10,2,1],
              [1,4,-1],[2,7,-1],[3,8,-1],[4,9,-1],[7,10,-1],[8,1,1],[9,2,1],[10,3,1],
              
              [5,4,1],[5,7,-1],[5,8,-1],[5,9,-1],[5,10,-1],[5,1,1],[5,2,1],[5,3,1],
              [6,4,1],[6,7,-1],[6,8,-1],[6,9,-1],[6,10,-1],[6,1,1],[6,2,1],[6,3,1],
              [5,6,-1], [6,5,1],    
            
             ])

model = svm.SVC(kernel='linear', C=1.0).fit(X[:,:-1], X[:,-1])


# Get axis limits and create a grid to evaluate the model upon.
ax = plt.gca()

xx = np.linspace(0, 12)
yy = np.linspace(0, 12 )
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = model.decision_function(xy).reshape(XX.shape)

# Plot decision boundary and margins.
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# Highlight the support vectors.
ax.scatter(model.support_vectors_[:, 0], model.support_vectors_[:, 1], s=100,
           linewidth=1, facecolors='none', edgecolors='k')

# show the plot visually
plt.scatter(X[:, 0], X[:, 1],c=X[:,-1])
plt.xlim(0,12)
plt.ylim(0,12)
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
prediction = model.predict(test)

ax.contour(XX, YY, Z, alpha=0.5)

plt.show()
# Calculate the percentage accuracy rate on test set
print(accuracy_score(np.array(X1)[:,-1], np.array(prediction)) * 100)
print(accuracy_score(np.array(X1)[:,-1], np.array(prediction), normalize=False))
# Out:
# No handles with labels found to put in legend.
# 100.0
# 90

# %%
test = np.array([
              [1,2],[2,3],[3,4],[4,7],[7,8],[8,9],[9,10],[10,1],
              [1,3],[2,4],[3,7],[4,8],[7,9],[8,10],[9,1],[10,2],
              [1,4],[2,7],[3,8],[4,9],[7,10],[8,1],[9,2],[10,3],
              
              [5,4],[5,7],[5,8],[5,9],[5,10],[5,1],[5,2],[5,3],
              [6,4],[6,7],[6,8],[6,9],[6,10],[6,1],[6,2],[6,3],
              [5,6],[6,5],    
              
              [1,7],[2,8],[3,9],[4,10],[7,1],[8,2],[9,3],[10,4],
              [1,8],[2,9],[3,10],[4,1],[7,2],[8,3],[9,4],[10,7],
              [1,9],[2,10],[3,1],[4,2],[7,3],[8,4],[9,7],[10,8],
              [1,10],[2,1],[3,2],[4,3],[7,4],[8,7],[9,8],[10,9],
              [1,5],[2,5],[3,5],[4,5],[7,5],[8,5],[9,5],[10,5],
              [1,6],[2,6],[3,6],[4,6],[7,6],[8,6],[9,6],[10,6]
             ])

X = np.array([
              [1,2,-1],[10,1,1],[4,10,-1] , [2,2,-1]
              
             ])

model = svm.SVC(kernel='linear', C=1.0).fit(X[:,:-1], X[:,-1])





# show the plot visually
plt.scatter(X[:, 0], X[:, 1],c=X[:,-1])
plt.xlim(0,12)
plt.ylim(0,12)
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
prediction = model.predict(test)

ax.contour(XX, YY, Z, alpha=0.5)

plt.show()


# Calculate the percentage accuracy rate on test set
print(accuracy_score(np.array(X1)[:,-1], np.array(prediction)) * 100)
print(accuracy_score(np.array(X1)[:,-1], np.array(prediction), normalize=False))
# Out:
# No handles with labels found to put in legend.
# 81.11111111111111
# 73
